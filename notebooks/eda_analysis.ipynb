# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
permit_df = pd.read_csv('../data/raw/issued-building-permits.csv', sep=';', encoding='utf-8')

# %%
permit_df
# Out:
#         PermitNumber PermitNumberCreatedDate   IssueDate  PermitElapsedDays  \
# 0      DB-2022-05477              2022-12-13  2023-06-01                170
# 1      BP-2023-04066              2023-11-07  2024-04-24                169
# 2      DB-2024-02839              2024-07-29  2025-10-03                431
# 3      DB-2024-02404              2024-06-27  2024-11-22                148
# 4      BP-2024-04723              2024-11-28  2025-06-23                207
# ...              ...                     ...         ...                ...
# 49655  DB-2018-00416              2018-01-25  2018-09-21                239
# 49656  DB-2018-00419              2018-01-25  2018-09-21                239
# 49657  DB-2016-04667              2016-12-23  2017-08-21                241
# 49658  BP-2019-02685              2019-06-14  2019-07-10                 26
# 49659  BP-2019-00012              2019-01-02  2019-01-30                 28
#
#        ProjectValue             TypeOfWork  \
# 0         179987.50           New Building
# 1         900000.00           New Building
# 2         800000.00           New Building
# 3         880000.00           New Building
# 4              0.00           New Building
# ...             ...                    ...
# 49655     883000.00           New Building
# 49656     225000.00           New Building
# 49657     221500.00           New Building
# 49658     150000.00  Addition / Alteration
# 49659     118785.44  Addition / Alteration
#
#                                             Address  \
# 0               108 W 45TH AVENUE #3, Vancouver, BC
# 1         7951 FRENCH STREET, Vancouver, BC V6P 4V8
# 2         3563 W 32ND AVENUE, Vancouver, BC V6S 1Z1
# 3         3910 W 24TH AVENUE, Vancouver, BC V6S 1M2
# 4            2816 GLEN DRIVE, Vancouver, BC V5T 4B8
# ...                                             ...
# 49655  4857 TRAFALGAR STREET, Vancouver, BC V6L 2N1
# 49656  4863 TRAFALGAR STREET, Vancouver, BC V6L 2N1
# 49657      333 E 18TH AVENUE, Vancouver, BC V5V 1E7
# 49658       1755 HARO STREET, Vancouver, BC V6G 1H2
# 49659       1501 HARO STREET, Vancouver, BC V6G 1G4
#
#                                       ProjectDescription  \
# 0      Low Density Housing - New Building - To constr...
# 1      High Density Housing / Commercial - New Buildi...
# 2      Low Density Housing - New Building - To constr...
# 3      Low Density Housing - New Building - To constr...
# 4      High Density Housing / Commercial - New Buildi...
# ...                                                  ...
# 49655  Low Density Housing - New Building - To constr...
# 49656  Low Density Housing - New Building - To constr...
# 49657  Low Density Housing - New Building - To constr...
# 49658  Field Review - Addition / Alteration - Interio...
# 49659  Field Review - Addition / Alteration - #806, #...
#
#                                     PermitCategory  \
# 0                  New Build - Low Density Housing
# 1                                              NaN
# 2                  New Build - Low Density Housing
# 3                  New Build - Low Density Housing
# 4                                              NaN
# ...                                            ...
# 49655              New Build - Low Density Housing
# 49656              New Build - Low Density Housing
# 49657               New Build - Standalone Laneway
# 49658  Renovation - Residential - Lower Complexity
# 49659  Renovation - Residential - Lower Complexity
#
#                                                Applicant  \
# 0                         QI LI DBA: LQ Design GROUP Ltd
# 1                         QI LI DBA: LQ Design GROUP Ltd
# 2                         QI LI DBA: LQ Design GROUP Ltd
# 3                         QI LI DBA: LQ Design GROUP Ltd
# 4                         QI LI DBA: LQ Design GROUP Ltd
# ...                                                  ...
# 49655                         Bryn Davidson DBA: Lanefab
# 49656                         Bryn Davidson DBA: Lanefab
# 49657                         Bryn Davidson DBA: Lanefab
# 49658  Gordon Chan DBA: McCuaig & Associates Engineer...
# 49659  Gordon Chan DBA: McCuaig & Associates Engineer...
#
#                                       ApplicantAddress    PropertyUse  \
# 0      2161 LAWSON AVE \r\nWEST VANCOUVER, BC  V7V 2E1  Dwelling Uses
# 1      2161 LAWSON AVE \r\nWEST VANCOUVER, BC  V7V 2E1  Dwelling Uses
# 2      2161 LAWSON AVE \r\nWEST VANCOUVER, BC  V7V 2E1  Dwelling Uses
# 3      2161 LAWSON AVE \r\nWEST VANCOUVER, BC  V7V 2E1  Dwelling Uses
# 4      2161 LAWSON AVE \r\nWEST VANCOUVER, BC  V7V 2E1  Dwelling Uses
# ...                                                ...            ...
# 49655     3728 Commercial St\r\nVancouver, BC  V5N 4G2  Dwelling Uses
# 49656     3728 Commercial St\r\nVancouver, BC  V5N 4G2  Dwelling Uses
# 49657     3728 Commercial St\r\nVancouver, BC  V5N 4G2  Dwelling Uses
# 49658     200-3999 Henning Dr.\r\nBurnaby, BC  V5C 6P9  Dwelling Uses
# 49659     200-3999 Henning Dr.\r\nBurnaby, BC  V5C 6P9  Dwelling Uses
#
#                             SpecificUseCategory  \
# 0                                 Laneway House
# 1                             Multiple Dwelling
# 2             Single Detached House w/Sec Suite
# 3      Duplex w/Secondary Suite,Secondary Suite
# 4                         Single Detached House
# ...                                         ...
# 49655         Single Detached House w/Sec Suite
# 49656                             Laneway House
# 49657                             Laneway House
# 49658                         Multiple Dwelling
# 49659                         Multiple Dwelling
#
#                   BuildingContractor  \
# 0                                NaN
# 1                                NaN
# 2        Vola Management Corporation
# 3        JETFINITY DESIGN BUILD INC.
# 4                                NaN
# ...                              ...
# 49655       Lanefab Design Build Ltd
# 49656       Lanefab Design Build Ltd
# 49657       Lanefab Design Build Ltd
# 49658                            NaN
# 49659  Solid General Contractors Inc
#
#                             BuildingContractorAddress  IssueYear  \
# 0                                                 NaN       2023
# 1                                                 NaN       2024
# 2         1329 BALFOUR AV  \r\nVancouver, BC  V6H 1X8       2025
# 3                                                 NaN       2024
# 4                                                 NaN       2025
# ...                                               ...        ...
# 49655  3728 COMMERCIAL ST  \r\nVancouver, BC  V5N 4G2       2018
# 49656  3728 COMMERCIAL ST  \r\nVancouver, BC  V5N 4G2       2018
# 49657  3728 COMMERCIAL ST  \r\nVancouver, BC  V5N 4G2       2017
# 49658                                             NaN       2019
# 49659     4163 McConnell Dr  \r\nBurnaby, BC  V5A 3J7       2019
#
#             GeoLocalArea                                               Geom  \
# 0               Oakridge  {"coordinates": [-123.1086422, 49.229261], "ty...
# 1                Marpole  {"coordinates": [-123.1393874, 49.2137408], "t...
# 2      Dunbar-Southlands  {"coordinates": [-123.1838783, 49.2435833], "t...
# 3      Dunbar-Southlands  {"coordinates": [-123.1912535, 49.2508193], "t...
# 4         Mount Pleasant  {"coordinates": [-123.0814044, 49.2592904], "t...
# ...                  ...                                                ...
# 49655      Arbutus Ridge  {"coordinates": [-123.1659732, 49.242673], "ty...
# 49656      Arbutus Ridge  {"coordinates": [-123.1656234, 49.2426384], "t...
# 49657         Riley Park  {"coordinates": [-123.0971969, 49.2547684], "t...
# 49658           West End  {"coordinates": [-123.1355427, 49.2905353], "t...
# 49659           West End  {"coordinates": [-123.1323178, 49.2884502], "t...
#
#       YearMonth              geo_point_2d
# 0       2023-06   49.229261, -123.1086422
# 1       2024-04  49.2137408, -123.1393874
# 2       2025-10  49.2435833, -123.1838783
# 3       2024-11  49.2508193, -123.1912535
# 4       2025-06  49.2592904, -123.0814044
# ...         ...                       ...
# 49655   2018-09   49.242673, -123.1659732
# 49656   2018-09  49.2426384, -123.1656234
# 49657   2017-08  49.2547684, -123.0971969
# 49658   2019-07  49.2905353, -123.1355427
# 49659   2019-01  49.2884502, -123.1323178
#
# [49660 rows x 20 columns]

# %% [markdown]
# **User Story 4:**
# As a city planner, I want to see a time series of permit volume per month or season, with the ability to forecast future building permits, so that I can detect seasonal patterns and plan departmental workload accordingly.

# %%
permit_df['PermitNumberCreatedDate'] = pd.to_datetime(permit_df['PermitNumberCreatedDate'])

plt.figure(figsize=(12, 6))
permit_df['PermitNumberCreatedDate'] = pd.to_datetime(permit_df['PermitNumberCreatedDate'])
permit_df.groupby(permit_df['PermitNumberCreatedDate'].dt.to_period('M')).size().plot()
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Permit Count Over Time')
plt.show()

# %%
monthly_avg = permit_df.groupby(permit_df['PermitNumberCreatedDate'].dt.month).size()

plt.figure(figsize=(10, 6))
monthly_avg.plot(kind='bar')
plt.xlabel('Month')
plt.ylabel('Average Count')
plt.title('Average Permit Count by Month')
plt.xticks(range(12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
                        'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45)
plt.show()
